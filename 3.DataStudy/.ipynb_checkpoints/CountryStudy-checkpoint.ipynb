# %%
# Needed libraries

import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns

from shapely.geometry import Point
from bokeh.plotting import figure, save,show
from bokeh.models import ColumnDataSource, HoverTool, LogColorMapper
from bokeh.io import output_notebook,output_file
from bokeh.models import ColumnDataSource, GMapOptions
from bokeh.plotting import gmap

from matplotlib import cm

# %%
# Load the country history
raw_df = pd.read_csv('../../../../og_data/ST-DBSCAN/ST_with_country.csv', parse_dates=['ts'],\
                       low_memory=False)

# %%
raw_df
# Out:
#                               ts aircraft_id    alt  speed  Direction  \
# 0      2018-04-18 17:09:10+00:00     HBAL088  64700      9        251
# 1      2018-04-18 17:14:14+00:00     HBAL088  64600      8        255
# 2      2018-04-18 17:15:25+00:00     HBAL088  64600      9        257
# 3      2018-04-18 18:08:59+00:00     HBAL088  64400     10        240
# 4      2018-04-18 18:10:32+00:00     HBAL088  64600     10        236
# ...                          ...         ...    ...    ...        ...
# 680636 2020-04-14 03:42:02+00:00     HBAL019  62000     13        291
# 680637 2020-04-14 03:47:04+00:00     HBAL019  62200     13        292
# 680638 2020-04-14 03:52:08+00:00     HBAL019  62300     12        265
# 680639 2020-04-14 03:57:05+00:00     HBAL019  62400     12        260
# 680640 2020-04-14 03:57:12+00:00     HBAL019  62500     12        260
#
#        registration_id       lat        lon  trip_id  cluster  \
# 0               N211LB -8.963215 -29.729620  HBAL088       -1
# 1               N211LB -8.965897 -29.741991  HBAL088       -1
# 2               N211LB -8.966519 -29.744867  HBAL088       -1
# 3               N211LB -9.021498 -29.865860  HBAL088       -1
# 4               N211LB -9.023941 -29.869825  HBAL088       -1
# ...                ...       ...        ...      ...      ...
# 680636          N329LB -5.854660 -75.961006  HBAL019        0
# 680637          N329LB -5.846356 -75.978180  HBAL019        0
# 680638          N329LB -5.843190 -75.995888  HBAL019        0
# 680639          N329LB -5.846076 -76.013840  HBAL019        0
# 680640          N329LB -5.846146 -76.014267  HBAL019        0
#
#            time_since_last_record  episode  stationary country country_code
# 0                             NaN     -1.0       False     NaN          NaN
# 1                             NaN     -1.0       False     NaN          NaN
# 2                             NaN     -1.0       False     NaN          NaN
# 3                             NaN     -1.0       False     NaN          NaN
# 4                             NaN     -1.0       False     NaN          NaN
# ...                           ...      ...         ...     ...          ...
# 680636  0 days 00:05:02.000000000     48.0        True    Peru          PER
# 680637  0 days 00:05:02.000000000     48.0        True    Peru          PER
# 680638  0 days 00:05:04.000000000     48.0        True    Peru          PER
# 680639  0 days 00:04:57.000000000     48.0        True    Peru          PER
# 680640  0 days 00:00:07.000000000     48.0        True    Peru          PER
#
# [680641 rows x 15 columns]

# %%
raw_df.speed.max()
# Out:
# 746

# %%
bl_countries = raw_df[raw_df['country'].notnull()]

# %%
heatmap_df = bl_countries.groupby(['registration_id', 'country'])['ts'].count().reset_index()

# Reshape the data to adapt it to the heatmap
heatmap_df = heatmap_df.pivot(index='country', columns='registration_id', values='ts')
heatmap_df = heatmap_df.fillna(0)

heatmap_df['Total'] = heatmap_df.iloc[:, 0:len(heatmap_df.columns)].sum(axis=1)
mask = np.zeros((len(heatmap_df), len(heatmap_df.columns)))
mask[:,len(heatmap_df.columns)-1] = True


# Set the width and height of the figure
plt.figure(figsize=(10,15))

ax = sns.heatmap(data=heatmap_df, mask=mask, vmin=heatmap_df.values[:,:len(heatmap_df.columns)-1].ravel().min(),\
                         vmax=heatmap_df.values[:,:len(heatmap_df.columns)-1].ravel().max(),\
                         cmap='Reds', linewidths=.5, annot=True, fmt='g')

for (j,i), label in np.ndenumerate(heatmap_df.values):
    if i == len(heatmap_df.columns)-1:
        ax.text(i+0.5, j+0.5, label)

bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)

b = plt.xlabel("Loon")
b = plt.ylabel("Country")

# %%
# Top visited countries
heatmap_df.sort_values('Total', ascending=False).head(10)
# Out:
# registration_id            N211LB   N235LB   N238LB   N252LB   N271LB  \
# country
# Peru                       8492.0  33817.0  54584.0  39951.0  36544.0
# Brazil                     8115.0  18009.0  31130.0  18872.0  16292.0
# United States of America  11848.0     62.0  10919.0  11783.0    196.0
# Ecuador                     547.0   3250.0   3826.0   8567.0   2007.0
# Colombia                      0.0      0.0   6055.0   8294.0   3159.0
# Australia                     0.0      0.0   2309.0   4613.0      0.0
# Mexico                      911.0    259.0   1422.0   2816.0   1420.0
# Argentina                     0.0   1615.0    717.0   2634.0    684.0
# Bolivia                       0.0     35.0   3031.0     19.0      0.0
# Suriname                      0.0      0.0   1150.0   3016.0      0.0
#
# registration_id            N329LB     Total
# country
# Peru                      55101.0  228489.0
# Brazil                    23728.0  116146.0
# United States of America  10819.0   45627.0
# Ecuador                    2591.0   20788.0
# Colombia                   1243.0   18751.0
# Australia                  2449.0    9371.0
# Mexico                     1383.0    8211.0
# Argentina                  1429.0    7079.0
# Bolivia                    2482.0    5567.0
# Suriname                      0.0    4166.0

# %%
# Let's check the countries where the loons have stayed

episode_start_times = bl_countries.loc[bl_countries.stationary == True]\
                                    .groupby(['registration_id', 'cluster', 'episode'])['ts'].min().reset_index()

episode_end_times = bl_countries.loc[bl_countries.stationary == True]\
                                    .groupby(['registration_id', 'cluster', 'episode'])['ts'].max().reset_index()

client_countries = bl_countries.loc[bl_countries.stationary == True]\
                                    .groupby(['registration_id', 'cluster', 'episode'])['country']\
                                        .agg(lambda x:x.value_counts().index[0]).reset_index()

client_countries['service_start'] = episode_start_times['ts']
client_countries['service_end'] = episode_end_times['ts']
client_countries['service_duration'] = client_countries['service_end'] - client_countries['service_start']

client_countries = client_countries.sort_values('service_duration', ascending=False)

client_countries
# Out:
#     registration_id  cluster  episode                           country  \
# 100          N329LB        0     46.0                              Peru
# 25           N238LB        0     37.0                              Peru
# 26           N238LB        0     38.0                              Peru
# 21           N238LB        0     24.0                              Peru
# 12           N238LB        0      2.0                              Peru
# ..              ...      ...      ...                               ...
# 40           N238LB        9      7.0                       Puerto Rico
# 37           N238LB        5      0.0                          Barbados
# 38           N238LB        5      1.0  Saint Vincent and the Grenadines
# 64           N252LB        2      0.0                       Puerto Rico
# 49           N252LB        0     13.0                           Ecuador
#
#                 service_start               service_end service_duration
# 100 2020-03-03 05:28:32+00:00 2020-03-11 23:43:25+00:00  8 days 18:14:53
# 25  2020-02-12 03:23:17+00:00 2020-02-18 16:43:34+00:00  6 days 13:20:17
# 26  2020-03-17 10:34:18+00:00 2020-03-23 16:44:48+00:00  6 days 06:10:30
# 21  2019-05-07 11:10:27+00:00 2019-05-13 14:57:39+00:00  6 days 03:47:12
# 12  2018-12-13 07:28:11+00:00 2018-12-19 06:50:14+00:00  5 days 23:22:03
# ..                        ...                       ...              ...
# 40  2020-02-27 22:46:17+00:00 2020-02-28 05:41:29+00:00  0 days 06:55:12
# 37  2018-05-11 14:11:40+00:00 2018-05-11 15:10:44+00:00  0 days 00:59:04
# 38  2019-01-24 08:50:52+00:00 2019-01-24 09:21:39+00:00  0 days 00:30:47
# 64  2018-11-19 01:14:00+00:00 2018-11-19 01:43:41+00:00  0 days 00:29:41
# 49  2019-01-07 03:56:52+00:00 2019-01-07 04:05:01+00:00  0 days 00:08:09
#
# [107 rows x 7 columns]

# %%
# Now we can get some insights
client_countries.groupby()
# Out:
#     registration_id  cluster  episode                        ts
# 0            N211LB        2      0.0 2018-09-06 16:48:13+00:00
# 1            N211LB        3      0.0 2020-02-11 18:27:08+00:00
# 2            N211LB        3      1.0 2020-02-16 14:33:34+00:00
# 3            N211LB        3      2.0 2020-03-15 08:05:00+00:00
# 4            N235LB        0      1.0 2019-12-28 19:52:19+00:00
# ..              ...      ...      ...                       ...
# 102          N329LB        0     48.0 2020-04-09 15:23:06+00:00
# 103          N329LB        1      0.0 2018-05-24 03:45:06+00:00
# 104          N329LB        1      2.0 2020-02-16 22:39:53+00:00
# 105          N329LB        2      0.0 2019-10-20 18:23:47+00:00
# 106          N329LB        6      0.0 2018-05-28 15:42:24+00:00
#
# [107 rows x 4 columns]

# %%
episode_end_times
# Out:
#     registration_id  cluster  episode                        ts
# 0            N211LB        2      0.0 2018-09-09 11:43:24+00:00
# 1            N211LB        3      0.0 2020-02-13 23:26:36+00:00
# 2            N211LB        3      1.0 2020-02-18 08:18:57+00:00
# 3            N211LB        3      2.0 2020-03-17 16:09:02+00:00
# 4            N235LB        0      1.0 2019-12-30 00:22:28+00:00
# ..              ...      ...      ...                       ...
# 102          N329LB        0     48.0 2020-04-14 03:57:12+00:00
# 103          N329LB        1      0.0 2018-05-24 12:39:39+00:00
# 104          N329LB        1      2.0 2020-02-17 17:10:53+00:00
# 105          N329LB        2      0.0 2019-10-21 08:05:23+00:00
# 106          N329LB        6      0.0 2018-05-29 14:42:58+00:00
#
# [107 rows x 4 columns]

# %%
episode_country
# Out:
#     registration_id  cluster  episode                   country
# 0            N211LB        2      0.0  United States of America
# 1            N211LB        3      0.0                      Peru
# 2            N211LB        3      1.0                      Peru
# 3            N211LB        3      2.0                      Peru
# 4            N235LB        0      1.0                      Peru
# ..              ...      ...      ...                       ...
# 102          N329LB        0     48.0                      Peru
# 103          N329LB        1      0.0               Puerto Rico
# 104          N329LB        1      2.0                  Anguilla
# 105          N329LB        2      0.0                      Peru
# 106          N329LB        6      0.0                    Panama
#
# [107 rows x 4 columns]
